# %%
import os
import numpy as np
import numpy.random as npr
import matplotlib.pyplot as plt
import pandas as pd
from tqdm import tqdm
from scipy.integrate import odeint
from Utils.Models import *
from Utils.EABCSMC import *
from Utils.Preconditioning import * 

# %config InlineBackend.figure_format = 'retina' 
# %matplotlib inline

# %%
def SIRD_reduced_30_new(z, t, beta0, gamma, kappa, mu0):

    I, R, D = z
    
    #S0 = 1048000 * beta0 
    S0 = kappa * 100000 * beta0
    S = S0 - I - R - D
    mu = mu0 * (1/(t+1))
    beta = beta0* np.exp(-(9.72588371e-02 * beta0) * t)
    dS = - beta * I * S / S0
    dI = beta * I * S / S0 - gamma * I - mu * I
    dR = gamma * I 
    dD = mu * I

    dzdt = [dI, dR, dD]
    return dzdt


def SEIRD(z, t, S0, beta0, gamma, mu0):
    if t == 0:
        I, R, D, E = z
        E = 11.42 * beta0
    else:
        I, R, D, E = z
    S0 = 100000*S0
    S = S0 - I - R - D - E
    mu = mu0 * (1/(t+1))
    alpha = 5.61 * beta0
    beta = beta0 * np.exp(-0.0952* beta0 * t) 
    dS = - beta * I * S / S0
    dE = beta * I * S / S0 - alpha * E
    dI = alpha * E - gamma * I - mu * I
    dR = gamma * I
    dD = mu * I

    dzdt = [dI, dR, dD, dE]
    return dzdt

# %%
italy = pd.read_csv('Data/Sird_bigdata.csv')
italy.fillna(0, inplace = True)

Precond = Preconditioner(SEIRD, 'SEIRD')

Precond.preprocess_data(data=italy, start=0, eff=30, ext=150)
popt, pcov = Precond.fit(p0 = (5.45, 0.44, 0.020, 0.30), bounds=([0, 0, 0, 0], [20, 3, 3,  3]))

# %%
simul_yy =  odeint(SEIRD, (221,7,1,0), np.arange(150), args=tuple(np.reshape(popt,(1,-1))[0]))
plot_traj_SIRD(simul_yy)
plot_traj_gray_SIRD(Precond.extended_y)

# %%
extended_yy = np.append(Precond.extended_y[:,0],Precond.extended_y[:,1])
extended_yy = np.append(extended_yy,Precond.extended_y[:,2])

# %%
residuals = np.ravel(extended_yy) - Precond.fit_odeint(np.arange(150), *popt)
ss_res = np.sum(residuals**2)

ss_tot = np.sum((np.ravel(extended_yy)-np.ravel(np.mean(extended_yy)))**2)

r_squared = 1 - (ss_res / ss_tot)

r_squared
# Out:
# 0.961574273558905

# %%
def compute_corr(covariance):
    v = np.sqrt(np.diag(covariance))
    outer_v = np.outer(v, v)
    correlation = covariance / outer_v
    correlation[covariance == 0] = 0
    return correlation

import seaborn as sns

corr = compute_corr(pcov)

plt.figure(figsize=(10,8))

sns.heatmap(corr, annot = True)

plt.title("Correlation Matrix")
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
lambda_ranges = [lambda : npr.uniform(low = 0.5, high = 5), lambda: npr.uniform(low = 0.5, high = 5), lambda: npr.uniform(low = 0.5, high = 5),
                lambda: npr.uniform(low = 0.5, high = 5)]
prior_means =  np.array([5, 0.388,  0.02922435,  0.30892933])

Sampler = EABCSMCSampler(true_y = Precond.true_yy, ODEmodel = Precond.fit_odeint, num_param = len(popt), numerical_estimate = popt, final_time = 30, 
                         prior_means = prior_means, lambda_ranges = lambda_ranges, n_jobs = 3)

# %%
lambda_ranges
# Out:
# [<function __main__.<lambda>()>,
#  <function __main__.<lambda>()>,
#  <function __main__.<lambda>()>,
#  <function __main__.<lambda>()>]

# %%
npr.seed(42)
Sampler.fit(niters=3000, eps_schedule=[2, 1, 1/2, 1/4, 1/8], niters_schedule=[10, 5, 5, 5, 30])
Sampler.pairplot()
# Out:
#   0%|                                                                                        | 0/30000 [00:00<?, ?it/s]
# Borders estimation start...
# 100%|███████████████████████████████████████████████████████████████████████████| 30000/30000 [02:01<00:00, 246.27it/s]
#   0%|▏                                                                             | 30/15000 [00:00<00:51, 289.23it/s]
# Acceptance rate:  0.004533333333333334
# Borders estimation completed, starting preprocessing...
# Borders: [1.6634444140451947, 0.3880986183187019, 0.0047821376955034176, 0.0021375544682363384]
# 100%|███████████████████████████████████████████████████████████████████████████| 15000/15000 [01:24<00:00, 178.06it/s]
#   0%|                                                                               | 12/15000 [00:00<03:10, 78.64it/s]
# Acceptance rate:  0.0032
# Preprocessing completed, starting ABC-SMC
# 100%|███████████████████████████████████████████████████████████████████████████| 15000/15000 [01:01<00:00, 244.91it/s]
#   0%|▏                                                                             | 30/15000 [00:00<01:03, 235.00it/s]
# Acceptance rate:  0.0224
# ABS-SMC round :  2
# 100%|███████████████████████████████████████████████████████████████████████████| 15000/15000 [01:29<00:00, 167.29it/s]
#   0%|                                                                               | 12/90000 [00:00<15:34, 96.26it/s]
# Acceptance rate:  0.0112
# ABS-SMC round :  3
# 100%|███████████████████████████████████████████████████████████████████████████| 90000/90000 [08:03<00:00, 186.01it/s]
# Acceptance rate:  0.007577777777777778

# %%
params =parameters

# %%
parameters = Sampler.parameters

# %%
np.save('parameters_seird_30.npy', parameters)

# %%
def plot_traj_SIRD(trajectories, width=1.):
    x2 = trajectories[:, 0]
    x3 = trajectories[:, 1]
    x4 = trajectories[:, 2]

    i = plt.plot(x2, linewidth=width, label='Infected', color = 'navy')
    r = plt.plot(x3, linewidth=width, label='Recovered', color = (.21,.39,.55))
    d = plt.plot(x4, linewidth=width, label='Deceased', color = (0.39,.72,1))

    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    # plt.title('Real SIRD')
    plt.title('SEIRD prediction at day 30')
    plt.tight_layout()
    
def plot_traj_SIRD2(trajectories, width=1.):
    x2 = trajectories[:, 0]
    x3 = trajectories[:, 1]
    x4 = trajectories[:, 2]
    color_ = (0,0,0.5)
    

    i = plt.plot(x2, linewidth=width/3,color = 'navy', linestyle = 'dashed' )
    r = plt.plot(x3, linewidth=width/3, color = (.21,.39,.55), linestyle = 'dashed')
    d = plt.plot(x4, linewidth=width/3,  color = (0.39,.72,1), linestyle = 'dashed')

    # plt.title('Real SIRD')
    plt.tight_layout()

# %%
# magari anche questo lo metto dentro all'abc sampler
# magari anche questo lo metto dentro all'abc sampler

fig = plt.figure(figsize = (12,8))

peak = []
day_peak = []
simul_all = []

for j in tqdm(range(parameters.shape[0])):
    simul_yy =  odeint(SEIRD, [221,1,7,0], np.arange(150), args=tuple(parameters[j]))
    simul_all.append(simul_yy)
    plot_traj_gray_SIRD(simul_yy)
    peak.append(max(simul_yy[:,0]))
    day_peak.append(np.argmax(simul_yy[:,0]))

simul_all = np.array(simul_all)
q95 = []
q05 = []
mean = []
sd = []
for i in range(150):
    q95.append([np.quantile(simul_all[:,i,0],0.975),np.quantile(simul_all[:,i,1],0.975),np.quantile(simul_all[:,i,2],0.975)])
    q05.append([np.quantile(simul_all[:,i,0],0.025),np.quantile(simul_all[:,i,1],0.025),np.quantile(simul_all[:,i,2],0.025)])
    mean.append([np.mean(simul_all[:,i,0]),np.mean(simul_all[:,i,1]),np.mean(simul_all[:,i,2])])
    sd.append([np.std(simul_all[:,i,0]),np.std(simul_all[:,i,1]),np.std(simul_all[:,i,2])])

q95 = np.array(q95)    
q05 = np.array(q05)  

plot_traj_SIRD2(q95)

plot_traj_SIRD2(q05)

plot_traj_SIRD(Precond.extended_y)

print(np.quantile(peak,0.025), np.quantile(peak,0.975))
print(np.quantile(day_peak,0.025), np.quantile(day_peak,0.975))
print(np.argmax(Precond.extended_y[:,0]))
print(np.max(Precond.extended_y[:,0]))

plt.ylabel('Number of individuals')
plt.xlabel('Time [days]')
plt.show()
plt.savefig('Seird_30days.png')
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 500/500 [00:10<00:00, 49.10it/s]
# 102312.05821942986 143552.4062576201
# 52.0 58.0
# 55
# 108257.0

# %%
PBR = 0
for i in range(31,150):
    PBR += np.sum([(Precond.extended_y[i][j] - mean[i][j] / sd[i][j])**2 for j in range(2)])

# %%
PBR
# Out:
# 2825534166995.441

# %%
PBR / 2825480187584.038
# Out:
# 1.0000191045089044

# %%
parameters[:,3]
# Out:
# array([0.28354599, 0.29131591, 0.29468846, 0.32261869, 0.2978943 ,
#        0.30111862, 0.29445009, 0.29416087, 0.31692035, 0.29979367,
#        0.33232576, 0.30241692, 0.32728727, 0.28023861, 0.29886495,
#        0.3113959 , 0.34537377, 0.33274757, 0.30352412, 0.29146156,
#        0.30096284, 0.2878459 , 0.33449722, 0.28694985, 0.31495394,
#        0.31930559, 0.2864668 , 0.31389386, 0.27858429, 0.33501105,
#        0.27051195, 0.29270598, 0.30874203, 0.2989762 , 0.28811216,
#        0.31160909, 0.31010798, 0.26703797, 0.31327619, 0.29382752,
#        0.28503908, 0.3094816 , 0.31845287, 0.32116454, 0.32265098,
#        0.31835566, 0.35269059, 0.2815838 , 0.32485606, 0.29015772,
#        0.32909455, 0.27856367, 0.30482749, 0.28743502, 0.28563805,
#        0.29798712, 0.29665163, 0.34179171, 0.33704686, 0.32511293,
#        0.29637646, 0.28804742, 0.29237736, 0.31968202, 0.33596553,
#        0.30588904, 0.32255891, 0.29600306, 0.33394498, 0.32536559,
#        0.28816695, 0.27605503, 0.32558644, 0.31316537, 0.28767722,
#        0.31725692, 0.26997721, 0.32938563, 0.30525958, 0.2889727 ,
#        0.34340154, 0.30061658, 0.31413543, 0.32977974, 0.28170413,
#        0.31810707, 0.3296345 , 0.29080444, 0.32654231, 0.30575815,
#        0.3154612 , 0.30981404, 0.2895724 , 0.34455632, 0.30931472,
#        0.32327091, 0.30849124, 0.30549081, 0.29441625, 0.35141805,
#        0.25774787, 0.30323661, 0.30903767, 0.29973584, 0.34920359,
#        0.29194835, 0.30929128, 0.29362931, 0.28792555, 0.31594164,
#        0.28101259, 0.30547335, 0.30373924, 0.34170514, 0.30059589,
#        0.30948933, 0.3073618 , 0.30827485, 0.32157504, 0.34590628,
#        0.27934593, 0.32748329, 0.34112497, 0.30093658, 0.30728244,
#        0.331492  , 0.31767107, 0.32218591, 0.29925594, 0.28923492,
#        0.336265  , 0.31031827, 0.31207046, 0.30173314, 0.3241596 ,
#        0.29658836, 0.30162473, 0.29664884, 0.28624919, 0.2724695 ,
#        0.29565475, 0.32775443, 0.29925361, 0.28595841, 0.27267679,
#        0.29564916, 0.29875999, 0.31964674, 0.35238444, 0.3207658 ,
#        0.32596369, 0.28838272, 0.31222995, 0.26607033, 0.2806863 ,
#        0.33413929, 0.27322194, 0.32114026, 0.32492875, 0.32685836,
#        0.32826905, 0.3056979 , 0.2595195 , 0.30188038, 0.32609272,
#        0.31152407, 0.3132205 , 0.30460333, 0.2870494 , 0.34723997,
#        0.32949877, 0.29177022, 0.31901154, 0.31593836, 0.33013852,
#        0.28170799, 0.2995893 , 0.30921922, 0.29513435, 0.33129404,
#        0.27894588, 0.29322274, 0.30456595, 0.30092601, 0.31127168,
#        0.29633065, 0.31498485, 0.30566171, 0.30194456, 0.28275409,
#        0.29370879, 0.28434035, 0.28727463, 0.29840343, 0.31369232,
#        0.30473822, 0.33558975, 0.33921806, 0.30627619, 0.32131718,
#        0.29518985, 0.28960373, 0.31689358, 0.28288522, 0.29972841,
#        0.30669003, 0.32206846, 0.30765888, 0.29266741, 0.33964384,
#        0.30063849, 0.28409868, 0.29924657, 0.2759127 , 0.31449677,
#        0.32994504, 0.29554475, 0.29046524, 0.28836444, 0.28600295,
#        0.28813515, 0.30161298, 0.28618577, 0.31820861, 0.277521  ,
#        0.32992297, 0.30724568, 0.28982386, 0.29861719, 0.32577103,
#        0.30050678, 0.3310595 , 0.28638061, 0.29774133, 0.29408735,
#        0.29558174, 0.30362282, 0.30320701, 0.34933751, 0.27118192,
#        0.30025142, 0.28887583, 0.30689705, 0.27078061, 0.31497512,
#        0.2557147 , 0.31000133, 0.30604425, 0.31374069, 0.3311391 ,
#        0.30462439, 0.30236054, 0.30890779, 0.28353038, 0.31899469,
#        0.34035602, 0.28988801, 0.33313496, 0.32709035, 0.27431348,
#        0.2991235 , 0.32627001, 0.32308065, 0.31521636, 0.28512001,
#        0.32378249, 0.29475919, 0.28776826, 0.31775792, 0.32929218,
#        0.31739827, 0.31216968, 0.30164065, 0.33836607, 0.26278354,
#        0.28464956, 0.30731875, 0.32876731, 0.32583139, 0.3241172 ,
#        0.3161234 , 0.27873042, 0.27443568, 0.29148361, 0.30791874])

# %%
t = np.arange(150)

fig = plt.figure(figsize = (10,7))

day_max = []

for j in range(parameters.shape[0]):
    plt.plot(t, parameters[j,1]* np.exp(-(0.0952 * parameters[j,1]) * t)/((parameters[j,3]/(t+1)) + parameters[j,2]), linewidth = 1, color = 'lightgray')
    day_max.append(np.argmax(parameters[j,1]* np.exp(-(0.0952 * parameters[j,1]) * t)/((parameters[j,3]/(t+1)) + parameters[j,2])))
    
plt.title('Rt predicted by SEIRD model')
plt.ylabel('Predicted Rt')
plt.xlabel('Time [days]')
print(min(day_max), max(day_max))
# Out:
# 10 11

# %%
np.quantile(params[:,1],0.025) , np.quantile(params[:,1],0.975)
# Out:
# (0.4870432435943577, 0.5170082800488083)
