# %%
load("Data/Covid-19.RData")

# %%
pmatch('IT',unique(COVID19$ID))
ids = unique(COVID19$ID)
# Out:
# [1] 6378

# %%
ids[startsWith(unique(COVID19$ID),'IT')]
# Out:
#   [1] "IT"    "ITC"   "ITC1"  "ITC11" "ITC12" "ITC13" "ITC14" "ITC15" "ITC16"
#  [10] "ITC17" "ITC18" "ITC1X" "ITC1Z" "ITC2"  "ITC20" "ITC2X" "ITC2Z" "ITC3"
#  [19] "ITC31" "ITC32" "ITC33" "ITC34" "ITC3X" "ITC3Z" "ITC4"  "ITC41" "ITC42"
#  [28] "ITC43" "ITC44" "ITC46" "ITC47" "ITC48" "ITC49" "ITC4A" "ITC4B" "ITC4C"
#  [37] "ITC4D" "ITC4X" "ITC4Z" "ITF"   "ITF1"  "ITF11" "ITF12" "ITF13" "ITF14"
#  [46] "ITF1X" "ITF1Z" "ITF2"  "ITF21" "ITF22" "ITF2X" "ITF2Z" "ITF3"  "ITF31"
#  [55] "ITF32" "ITF33" "ITF34" "ITF35" "ITF3X" "ITF3Z" "ITF4"  "ITF43" "ITF44"
#  [64] "ITF45" "ITF46" "ITF47" "ITF48" "ITF4X" "ITF4Z" "ITF5"  "ITF51" "ITF52"
#  [73] "ITF5X" "ITF5Z" "ITF6"  "ITF61" "ITF62" "ITF63" "ITF64" "ITF65" "ITF6X"
#  [82] "ITF6Z" "ITG"   "ITG1"  "ITG11" "ITG12" "ITG13" "ITG14" "ITG15" "ITG16"
#  [91] "ITG17" "ITG18" "ITG19" "ITG1X" "ITG2"  "ITG25" "ITG26" "ITG27" "ITG28"
# [100] "ITG2Y" "ITH"   "ITH1"  "ITH10" "ITH2"  "ITH20" "ITH3"  "ITH31" "ITH32"
# ...

# %%
df_ES = COVID19[COVID19$ID == 'ES',]

# %%
df_ES = COVID19[COVID19$ID == 'ES',]
write.csv(df_ES,"Data\\Covid_ES.csv", row.names = FALSE)

# %%
df_FR = COVID19[COVID19$ID == 'FR',]
write.csv(df_FR,"Data\\Covid_FR.csv", row.names = FALSE)

# %%
df_CN = COVID19[COVID19$ID == 'CN',]
write.csv(df_CN,"Data\\Covid_CN.csv", row.names = FALSE)
